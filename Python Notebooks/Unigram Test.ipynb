# %% [markdown]
# # Word2Vec Unigram Testing
#
# This Python Notebook is used for evaluation of the Word2Vec Unigram model. The section is broken down as follows:
#
# - Find most similar words from the selected word
# - Perform Syntactic Analysis
# - Perform Semantic Analysis
# - Find uncommon word among a list of words
# - Find cosine similarity among two words
# - Find the frequency count of a word
# - Check if a word is in the model
# - Print preview a list of words
# - Others (Vector space size)

# %%
from gensim.models import Word2Vec as w2v
# Out:
# C:\Users\MyPC\Anaconda3\lib\site-packages\gensim\utils.py:840: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# C:\Users\MyPC\Anaconda3\lib\site-packages\gensim\utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")

# %%
# Load Unigram model
FILE = "C:/Users/MyPC/Desktop/FYP/W2V Models/w2v_reddit_unigram_300d.bin"
model = w2v.load_word2vec_format(FILE, binary=True)

# %%
# Cell to find most similar words 
# One word for unigram: dragon, bleach, tottenham
# Two words for bigram: dragon_ball, barack_obama (UNDERSCORE NEEDED + BIGRAM MODEL LOADED)
model.most_similar("neuropsychopharmacology", topn=20)
# Out:
# [('biopsychology', 0.740115225315094),
#  ('astrochemistry', 0.7391058206558228),
#  ('neuroendocrinologist', 0.7296165227890015),
#  ('nanoscience', 0.7265405058860779),
#  ('neuropharmacology', 0.7247588038444519),
#  ('saltzberg', 0.7157706618309021),
#  ('ethnomusicology', 0.7156946659088135),
#  ('psychobiology', 0.7154250144958496),
#  ('nueroscience', 0.7147186994552612),
#  ('neuropsychiatry', 0.7140935659408569),
#  ('ichthyology', 0.710540235042572),
#  ('molbio', 0.7056220769882202),
#  ('oenology', 0.7056138515472412),
#  ('antropology', 0.7041956186294556),
#  ('biopsych', 0.7037904858589172),
#  ('neuroengineering', 0.7037561535835266),
#  ('nanoengineering', 0.7024978995323181),
#  ('psycholinguistics', 0.7002543210983276),
#  ('bioanthropology', 0.6995773315429688),
#  ('christmann', 0.698868989944458)]

# %%
# Cell for semantic evaluation (Ex. King - man + woman is approximately equal to queen)
model.most_similar(positive=["tokyo","malaysia"], negative=["japan"])
# Out:
# [('lumpur', 0.6737101674079895),
#  ('kuala', 0.6668090224266052),
#  ('taipei', 0.6401477456092834),
#  ('bangkok', 0.6113026142120361),
#  ('penang', 0.5809809565544128),
#  ('lampur', 0.5752942562103271),
#  ('toyko', 0.5550657510757446),
#  ('selangor', 0.5511509776115417),
#  ('singapore', 0.5502724647521973),
#  ('mumbai', 0.5481346249580383)]

# %%
# Cell for syntactic evaluation (Ex. walking - walk + swim is approximately equal to swimming)
model.most_similar(positive=["greenish","blue"], negative=["green"])
# Out:
# [('blueish', 0.7298511266708374),
#  ('greyish', 0.7232707738876343),
#  ('bluish', 0.7149738669395447),
#  ('pinkish', 0.705883264541626),
#  ('purplish', 0.7028074264526367),
#  ('brownish', 0.6946163773536682),
#  ('grayish', 0.6922476887702942),
#  ('reddish', 0.6911346316337585),
#  ('yellowish', 0.6770833134651184),
#  ('whitish', 0.6669460535049438)]

# %%
# Cell to check which word doesn't match among a group of words
model.doesnt_match("blue green yellow apple".split())
# Out:
# 'apple'

# %%
# Cell to check similarity among two words
model.similarity("titanic","rose")
# Out:
# 0.24046405589195533

# %%
# Count number of times a specific word occured in the 2015 Dataset
word = model.vocab['difu']
type(word.count)
# Out:
# int

# %%
# Check if word (Unigram) is in model. It is case-sensitive
'Dragon' in model
# Out:
# False

# %%
# A brief review of words in the model
count = 70

for index, word in enumerate(model.vocab):
    print(index, word, model.vocab[word].count)
    if index == count:
        break
# Out:
# 0 cockweasel 708272
# 1 frakken 449808
# 2 smirfs 428731
# 3 wiine 853778
# 4 rellying 753562
# 5 medsbuy 753745
# 6 kirah 642904
# 7 loltumblr 1027250
# 8 confutation 86362
# 9 desarmado 49277
# 10 whicy 268221
# 11 weekending 733123
# 12 mactaggart 193721
# 13 caprisun 1003736
# 14 studierte 202535
# 15 dourtmund 137290
# 16 namors 626101
# 17 gingered 700697
# 18 urzak 346864
# 19 alck 366608
# 20 hronis 322693
# 21 depraved 1120032
# 22 perichondrium 157468
# 23 tumakbo 799760
# 24 ximum 550855
# 25 bantam 1087697
# 26 fullon 866146
# 27 cachete 724355
# 28 nakakaiyak 347117
# 29 stoneberry 443653
# 30 parallelisms 855916
# 31 fueling 1122857
# 32 eliminiation 405126
# 33 budzilla 354658
# 34 divestitures 729040
# 35 badmannered 475022
# 36 celticsblog 720527
# 37 windtalkers 933967
# 38 fururama 700825
# 39 inevara 118029
# 40 ertragswert 64683
# 41 giffingtool 112915
# 42 dingens 93462
# 43 sommerdamm 674304
# 44 dickade 55306
# 45 conceration 23629
# 46 ujarnya 188641
# 47 iphy 359343
# 48 receptiveness 1019798
# 49 microcube 754417
# 50 proudmanlet 159038
# 51 sysinstall 78281
# 52 cambada 491529
# 53 bistrevsky 351495
# 54 sablich 106899
# 55 horngate 8558
# 56 fekaf 91361
# 57 partiel 346242
# 58 tidebuy 656835
# 59 blendon 438701
# 60 hysterz 557559
# 61 attenderen 265015
# 62 sylverant 709755
# 63 schicky 61459
# 64 vaxine 173682
# 65 zedxleppelin 230616
# 66 solidblues 768659
# 67 gensport 124034
# 68 echobelly 668600
# 69 jubilo 705610
# 70 euler 1109608

# %%
# Looking under the hood of Word2vec
# Use this cell as tips for K-Means Clustering
# Motivation: https://www.kaggle.com/c/word2vec-nlp-tutorial/details/part-3-more-fun-with-word-vectors

# Feature vector for each word(s) 
#print(model.syn0[0])

# Shape of the vocabulary
#print(model.syn0.shape)

# Get list of all keys (words)
#model.index2word[2000:3000]

# %%
# Do preliminary of K-Means testing using the first (1000,2000,4000) words using 250 clusters
from sklearn.cluster import KMeans
import time

# Specify the number of words and clusters
WORDS = 15000
CLUSTERS = 1000

# Get the word vectors and the word
word_vectors = model.syn0[:WORDS]
words = model.index2word[:WORDS]

# Initialize K-Means
k_means = KMeans( n_clusters = CLUSTERS )

# Fit the model, get the centroid number and calculate time
start = time.time()
idx = k_means.fit_predict(word_vectors)
end = time.time()

print("TIME TAKEN: ", end-start)

# %%
# Create a Word / Index dictionary
# Each vocabulary word is matched to a cluster center

word_centroid_map = dict(zip( words, idx ))

#type(word_centroid_map)

# %%
# Loop through the top N clusters

N = 100

for cluster in range(0, N):
    
    #Create array of words
    words = []
    
    for word, cluster_num in word_centroid_map.items():
        if cluster_num == cluster:
            words.append(word)
    
    print("CLUSTER NUMBER: %i" % (cluster))
    print("WORDS: ", words)
    print("\n\n")
# Out:
# CLUSTER NUMBER: 0
# WORDS:  ['invest', 'invested', 'wastes', 'spend', 'wasting', 'wasted', 'precious', 'waste', 'spent', 'devoted', 'wisely', 'worth', 'spare', 'spending', 'dedicate', 'devote', 'dedicated', 'spends', 'leisure']
#
#
#
# CLUSTER NUMBER: 1
# WORDS:  ['balloons', 'docking', 'balloon', 'capsule', 'fly', 'landing', 'shuttle', 'jet', 'flight', 'plane', 'aboard', 'helicopter', 'boat', 'boarding', 'chopper', 'airplanes', 'parachute', 'crane', 'elevator', 'cockpit', 'flying', 'cruise', 'airplane', 'spaceship']
#
#
#
# CLUSTER NUMBER: 2
# WORDS:  ['fiasco', 'ordeal', 'disappointment', 'nightmare', 'mistake', 'disgrace', 'meltdown', 'regret', 'affair', 'tantrum', 'debacle', 'betrayal', 'disaster', 'shame', 'surprise', 'shitstorm', 'embarrassment', 'tragedy', 'utter', 'scandal', 'clusterfuck', 'bummer']
#
#
#
# CLUSTER NUMBER: 3
# WORDS:  ['blitz', 'lulu', 'sivir', 'riven', 'nasus', 'zed', 'cho', 'kassadin', 'sai', 'fizz', 'vlad', 'ezreal', 'kat', 'talon', 'zac', 'urgot', 'gnar', 'azir', 'sejuani', 'graves', 'yasuo', 'rek', 'corki', 'leblanc', 'sion', 'rengar', 'jinx', 'kalista', 'maw', 'teemo', 'veigar', 'morgana', 'vayne', 'quinn', 'irelia', 'pantheon', 'katarina', 'fiora', 'yi', 'diana', 'shaco', 'thresh', 'vi', 'blanc', 'akali', 'annie', 'xerath', 'ahri', 'janna', 'rumble', 'lux', 'maokai', 'kog', 'nautilus', 'lucian', 'darius', 'sona', 'jax', 'nami', 'draven', 'leona', 'ashe', 'elise', 'gragas', 'nidalee', 'garen', 'caitlyn']
#
#
#
# CLUSTER NUMBER: 4
# WORDS:  ['exclude', 'pursue', 'oppose', 'accept', 'suspend', 'appeals', 'advocate', 'seek', 'embrace', 'mock', 'endorse', 'cling', 'declare', 'deem', 'disregard', 'opt', 'support', 'approval', 'dismiss', 'abandoning', 'qualify', 'terminate', 'forbid', 'criticize', 'abandon', 'deny', 'appeal', 'fail', 'propose', 'resent', 'rejects', 'condemn', 'ignore', 'concede', 'reject', 'approve', 'blindly', 'rejecting']
#
#
#
# CLUSTER NUMBER: 5
# WORDS:  ['slippery', 'rocks', 'mist', 'swamp', 'terrain', 'dust', 'goo', 'uphill', 'dirt', 'desert', 'cracks', 'mud', 'muddy', 'pits', 'pond', 'debris', 'icy', 'tar', 'grass', 'ground', 'tread', 'sand', 'gravel', 'snow', 'trench', 'dusty', 'pavement', 'turf']
#
#
#
# CLUSTER NUMBER: 6
# WORDS:  ['hard', 'unpredictable', 'inconvenient', 'chore', 'taxing', 'stale', 'jarring', 'challenging', 'clunky', 'exhausting', 'buggy', 'hassle', 'unpleasant', 'convenient', 'unbalanced', 'paced', 'irritating', 'daunting', 'chaotic', 'laggy', 'annoying', 'noisy', 'tedious', 'costly', 'impractical', 'distracting', 'stressful', 'repetitive', 'boring', 'confusing', 'inefficient', 'tiring', 'painful', 'wasteful', 'tempting', 'tricky', 'dull', 'bloated', 'intensive', 'difficult', 'tough', 'messy', 'frustrating', 'consuming', 'predictable']
#
#
#
# CLUSTER NUMBER: 7
# WORDS:  ['rappers', 'jay', 'snoop', 'thug', 'drake', 'kanye', 'dee', 'kim', 'pimp', 'tang', 'rapper', 'freddie', 'swift', 'iggy', 'vic', 'kendrick', 'jong', 'earl', 'biggie', 'wayne', 'schoolboy', 'beyonce', 'eminem', 'katy', 'bieber', 'wiz', 'ali', 'papa']
#
#
#
# CLUSTER NUMBER: 8
# WORDS:  ['classroom', 'professors', 'students', 'prof', 'instruction', 'educational', 'teacher', 'instructors', 'professor', 'teachers', 'instructor', 'faculty', 'standardized', 'ed', 'education', 'grading', 'program', 'curriculum']
#
#
#
# CLUSTER NUMBER: 9
# WORDS:  ['aa', 'sc', 'sn', 'eu', 'pr', 'qb', 'pg', 'cr', 'sd', 'iv', 'gs', 'tb', 'os', 'cd', 'fs', 'qo', 'ff', 'reg', 'hs', 'gr', 'fb', 'ns', 'cp', 'xx', 'sp', 'ip', 'ks', 'ct', 'lp', 'cm', 'wv', 'mb', 'dc', 'dd', 'kb', 'ss', 'ro', 'sq', 'db', 'yr', 'gm', 'pp', 've', 'eg', 'gp', 'ez', 'gv', 'mk', 'bn', 'dm', 'sm', 'br', 'cb', 'dk', 'hd', 'gw', 'sh', 'xl', 'wh', 'ls', 'ea', 'ug', 'bo', 'bc', 'pt', 'rs', 'tf', 'rp', 'gg', 'ap', 'mp', 'io', 'tp', 'bb', 'ts']
#
#
#
# CLUSTER NUMBER: 10
# WORDS:  ['achieved', 'upon', 'described', 'titled', 'constitutes', 'labeled', 'applied', 'viewed', 'conceived', 'expressed', 'category', 'classified', 'interpreted', 'represented', 'defining', 'directed', 'specified', 'considered', 'determined', 'perceived', 'chosen', 'labelled', 'evidenced', 'referred', 'defines', 'deemed', 'defined', 'identified']
#
#
#
# CLUSTER NUMBER: 11
# WORDS:  ['berserker', 'apex', 'nova', 'strike', 'savage', 'exo', 'primal', 'lone', 'commando', 'beast', 'wrath', 'brute', 'scorpion', 'buster', 'trooper', 'requiem', 'roar', 'ace', 'grunt', 'terra', 'berserk', 'banshee', 'stalker', 'inferno', 'reaper', 'mob', 'phoenix', 'goliath', 'gunslinger', 'atlas', 'nemesis', 'gladiator', 'spartan', 'rampage', 'butcher', 'frost', 'kraken', 'frenzy', 'samurai', 'bandit', 'vengeance', 'predator', 'fury']
#
#
#
# CLUSTER NUMBER: 12
# WORDS:  ['prejudice', 'poverty', 'institutional', 'cruelty', 'oppressive', 'oppressed', 'misogyny', 'bigotry', 'intolerance', 'segregation', 'sexism', 'affirmative', 'brutality', 'extremism', 'systemic', 'corruption', 'injustice', 'racial', 'patriarchy', 'exploitation', 'oppression', 'genocide', 'minorities', 'inequality', 'equality', 'rampant', 'persecution', 'systematic', 'homophobia', 'discrimination', 'violence', 'slavery', 'racism']
#
#
#
# CLUSTER NUMBER: 13
# WORDS:  ['memorial', 'event', 'halloween', 'festivals', 'engagement', 'prom', 'reception', 'valentines', 'christmas', 'easter', 'vacation', 'tribute', 'merry', 'celebration', 'holidays', 'anniversary', 'parade', 'reunion', 'honeymoon', 'holiday', 'rave', 'tour', 'disneyland', 'birthday', 'convention', 'xmas', 'funeral', 'thanksgiving', 'circus', 'blackout', 'celebrate', 'birthdays', 'feast', 'fest', 'stage', 'weddings', 'wedding', 'festival', 'venue', 'gig', 'ceremony', 'trip', 'concert', 'fireworks', 'bingo', 'concerts']
#
#
#
# CLUSTER NUMBER: 14
# WORDS:  ['flavors', 'ice', 'pepsi', 'iced', 'coca', 'rum', 'gum', 'candy', 'fruity', 'juices', 'tea', 'flavored', 'cola', 'dew', 'juice', 'lemonade', 'kool', 'vodka', 'champagne', 'coke', 'gin', 'soda']
#
#
#
# CLUSTER NUMBER: 15
# WORDS:  ['belly', 'butts', 'breasts', 'vaginas', 'genitals', 'ass', 'penises', 'nipple', 'arse', 'balls', 'tit', 'anus', 'dong', 'vagina', 'booty', 'crotch', 'cleavage', 'nipples', 'penis', 'pussy', 'boobs', 'boob', 'butthole', 'tummy', 'testicles', 'butt', 'dildo', 'titties', 'cock', 'dick', 'bum', 'tits', 'clit']
#
#
#
# CLUSTER NUMBER: 16
# WORDS:  ['shack', 'haul', 'garage', 'home', 'barn', 'factory', 'hut', 'office', 'booth', 'lab', 'cart', 'locker', 'mailbox', 'dock', 'vending', 'warehouse']
#
#
#
# CLUSTER NUMBER: 17
# WORDS:  ['harming', 'ruin', 'harms', 'risking', 'hurting', 'sacrificing', 'spoil', 'harm', 'care', 'cripple', 'injure', 'ruining', 'spoiling', 'hurt', 'hurts']
#
#
#
# CLUSTER NUMBER: 18
# WORDS:  ['flooding', 'venting', 'filter', 'draining', 'buildup', 'funnel', 'chamber', 'drains', 'vacuum', 'pumping', 'drain', 'pump', 'fluid', 'flow', 'injection', 'circulation', 'leak', 'leaks', 'vents', 'pumps', 'air', 'flowing', 'vent', 'trickle', 'sinks', 'leaking', 'chambers', 'flows']
#
#
#
# CLUSTER NUMBER: 19
# WORDS:  ['blacklist', 'privileges', 'passwords', 'task', 'login', 'malware', 'permission', 'addresses', 'credentials', 'security', 'access', 'registry', 'password', 'admin', 'reboot', 'administrator', 'permissions', 'user', 'address', 'root']
#
#
#
# CLUSTER NUMBER: 20
# WORDS:  ['central', 'western', 'rural', 'northern', 'west', 'southwest', 'north', 'south', 'midwest', 'southeast', 'coast', 'east', 'eastern', 'southern', 'northwest', 'northeast']
#
#
#
# CLUSTER NUMBER: 21
# WORDS:  ['tangible', 'secondary', 'notable', 'specific', 'separate', 'singular', 'distinctly', 'distinct', 'definite', 'particular', 'unique', 'different', 'primary', 'there', 'recognizable', 'main', 'strong', 'unified', 'shared', 'multi', 'single', 'seperate', 'clear', 'special']
#
#
#
# CLUSTER NUMBER: 22
# WORDS:  ['monetary', 'investor', 'inheritance', 'finance', 'investment', 'stock', 'earnings', 'lending', 'asset', 'commodity', 'bets', 'shares', 'stake', 'investing', 'financially', 'millionaire', 'leverage', 'taxable', 'capital', 'recession', 'winnings', 'billionaire', 'bonds', 'gamble', 'inflation', 'expense', 'financial', 'assets', 'investors', 'allocation', 'hedge', 'retirement', 'returns', 'buyout', 'interest', 'bond', 'contributions', 'equity', 'payout', 'payoff', 'collateral', 'wealth', 'borrowing', 'contribution', 'savings', 'finances', 'venture', 'portfolio', 'roth', 'dividends', 'stocks', 'estate', 'taxed', 'investments']
#
#
#
# CLUSTER NUMBER: 23
# WORDS:  ['exceptional', 'terrific', 'underrated', 'magnificent', 'excellent', 'incredible', 'stunning', 'beautifully', 'superb', 'great', 'fantastic', 'brilliant', 'phenomenal', 'flawless', 'amazing', 'perfect', 'impressive', 'notch', 'spectacular', 'remarkable', 'outstanding', 'stellar']
#
#
#
# CLUSTER NUMBER: 24
# WORDS:  ['modem', 'comcast', 'gateway', 'wireless', 'mbps', 'remote', 'fi', 'router', 'encrypted', 'routers', 'firewall', 'server', 'encryption', 'connection', 'service', 'tor', 'proxy', 'networking', 'providers', 'protocol', 'bandwidth', 'routing', 'telephone', 'wi', 'connections', 'ms', 'network', 'servers', 'broadband', 'backbone', 'networks', 'cisco', 'communications', 'wifi', 'provider', 'internet']
#
#
#
# CLUSTER NUMBER: 25
# WORDS:  ['bigots', 'politics', 'moderate', 'feminists', 'fringe', 'extremists', 'feminist', 'feminism', 'militant', 'conservative', 'leftist', 'activist', 'ideological', 'neo', 'advocates', 'political', 'wing', 'politically', 'partisan', 'liberal', 'libertarians', 'radical', 'conservatives', 'extremist', 'libertarian', 'reactionary', 'liberals', 'activists', 'progressive', 'lefty', 'nationalist']
#
#
#
# CLUSTER NUMBER: 26
# WORDS:  ['neville', 'rusev', 'rollins', 'shawn', 'ambrose', 'wrestle', 'wrestlemania', 'brock', 'taker', 'cesaro', 'owens', 'hart', 'divas', 'mania', 'promos', 'jericho', 'randy', 'lesnar', 'bray', 'seth', 'undertaker', 'bryan', 'orton', 'heel', 'wyatt', 'vince', 'macho', 'sting', 'ziggler', 'booker', 'kane', 'reigns', 'cena', 'feud', 'gimmick', 'lana', 'diva', 'hogan', 'paige', 'dean']
#
#
#
# CLUSTER NUMBER: 27
# WORDS:  ['digital', 'iso', 'copies', 'disc', 'compressed', 'disks', 'ds', 'blu', 'formats', 'floppy', 'disk', 'tapes', 'vinyl', 'digitally', 'rays', 'demos', 'ray', 'ware', 'discs', 'cube', 'cartridge']
#
#
#
# CLUSTER NUMBER: 28
# WORDS:  ['quran', 'believers', 'churches', 'theist', 'judaism', 'theists', 'protestant', 'mosque', 'muslims', 'religious', 'buddhist', 'mohammed', 'pastor', 'christian', 'agnostic', 'buddhism', 'baptist', 'fundamentalist', 'teachings', 'religions', 'vatican', 'scientology', 'muhammad', 'pope', 'atheist', 'muslim', 'orthodox', 'bible', 'biblical', 'islam', 'scripture', 'preach', 'secular', 'christianity', 'hindu', 'pagan', 'religion', 'reformed', 'blasphemy', 'jew', 'catholic', 'doctrine', 'christians', 'atheists', 'jewish', 'theology', 'catholics', 'church', 'mormon', 'atheism', 'catholicism', 'believer', 'mormons']
#
#
#
# CLUSTER NUMBER: 29
# WORDS:  ['cooking', 'chops', 'dishes', 'cooker', 'pans', 'bake', 'pan', 'baking', 'dressing', 'cooks', 'prep', 'pot', 'stir', 'frying', 'fry', 'cook', 'grill', 'recipes', 'dish', 'chef', 'recipe', 'boil']
#
#
#
# CLUSTER NUMBER: 30
# WORDS:  ['belichick', 'quarterback', 'sherman', 'flacco', 'manning', 'rookie', 'gronk', 'cutler', 'brees', 'brady', 'bradford', 'coy', 'drafted', 'drafting', 'draft', 'wilson', 'rounder', 'dalton', 'rivers', 'peyton', 'winston', 'mariota', 'suh', 'receivers', 'offseason', 'dez', 'foles', 'carr', 'punt', 'bs', 'newton', 'sacks', 'yards', 'peterson', 'tebow', 'goodell', 'rodgers', 'touchdown', 'revis', 'eli', 'tackles', 'romo', 'passer', 'fumble', 'harbaugh']
#
#
#
# CLUSTER NUMBER: 31
# WORDS:  ['pressing', 'pressed', 'scratch', 'scraping', 'wrapping', 'bending', 'touch', 'twisting', 'stuffing', 'shaking', 'covering', 'rubbing', 'biting', 'licking', 'hugging', 'kissing', 'brushing', 'touching', 'bare', 'rub', 'scratches', 'chewing', 'flashing', 'tapping', 'dipping', 'resting', 'scratching']
#
#
#
# CLUSTER NUMBER: 32
# WORDS:  ['restroom', 'fart', 'sweating', 'poo', 'poop', 'toilets', 'pee', 'peeing', 'sneeze', 'toilet', 'shitting', 'pissing', 'masturbating', 'naked', 'potty', 'showering', 'pooping', 'masturbate', 'breathing', 'fapping', 'jerking', 'shower', 'showers']
#
#
#
# CLUSTER NUMBER: 33
# WORDS:  ['month', 'overnight', 'hour', 'days', 'months', 'hrs', 'session', 'weeks', 'years', 'awhile', 'day', 'min', 'mins', 'yrs', 'ago', 'miles', 'minutes', 'hours', 'twice', 'minute', 'year', 'hr', 'yesterday', 'seconds', 'week']
#
#
#
# CLUSTER NUMBER: 34
# WORDS:  ['foolish', 'cowardly', 'cheating', 'lie', 'abusive', 'blatantly', 'unethical', 'sneaky', 'outright', 'knowingly', 'liars', 'greedy', 'shameless', 'dishonest', 'malicious', 'selfish', 'petty', 'crooked', 'immoral', 'lying', 'ruthless', 'corrupt', 'careless', 'blatant', 'irresponsible', 'scamming', 'scam', 'manipulative', 'borderline', 'reckless', 'shady']
#
#
#
# CLUSTER NUMBER: 35
# WORDS:  ['districts', 'scenarios', 'hubs', 'situations', 'parts', 'paths', 'environment', 'surrounding', 'regions', 'areas', 'instances', 'populated', 'places', 'buildings', 'zone', 'circles', 'neighborhoods', 'fields', 'developments', 'locations', 'communities', 'spots', 'area', 'sections', 'urban', 'maps', 'spaces', 'environments', 'zones', 'segments', 'cases', 'groups', 'stages', 'portions']
#
#
#
# CLUSTER NUMBER: 36
# WORDS:  ['deserves', 'deserve', 'deserved', 'destined', 'righteous', 'worthy', 'snowflake', 'entitled', 'deserving', 'spoiled']
#
#
#
# CLUSTER NUMBER: 37
# WORDS:  ['calculating', 'determine', 'compute', 'derive', 'simplify', 'measuring', 'adjust', 'gauge', 'formula', 'assess', 'subtract', 'graph', 'assign', 'equation', 'measured', 'figure', 'metric', 'pinpoint', 'inverse', 'predict', 'measurements', 'calculations', 'calculated', 'formulas', 'measure', 'measurement', 'calculate', 'proportional', 'chart', 'estimate', 'calculation', 'calculator', 'derivative', 'measures', 'accounted', 'determining', 'evaluate', 'analyze']
#
#
#
# CLUSTER NUMBER: 38
# WORDS:  ['putin', 'ottoman', 'occupation', 'gandhi', 'holocaust', 'comrade', 'russia', 'napoleon', 'union', 'nazis', 'soviet', 'colonial', 'moscow', 'superpower', 'war', 'stalin', 'poles', 'nazi', 'soviets', 'hitler', 'mao']
#
#
#
# CLUSTER NUMBER: 39
# WORDS:  ['shift', 'leaning', 'shifted', 'fading', 'advancing', 'switching', 'evolving', 'progressing', 'movement', 'changing', 'adjusting', 'transition', 'shaping', 'merging', 'shifting', 'adapting', 'moving', 'change', 'drifting', 'shifts', 'transitioning']
#
#
#
# CLUSTER NUMBER: 40
# WORDS:  ['murders', 'spree', 'prisoner', 'innocent', 'torture', 'suicide', 'crimes', 'homicide', 'commit', 'victims', 'murder', 'witnesses', 'assault', 'violent', 'crime', 'falsely', 'alleged', 'kidnapping', 'asylum', 'committed', 'rape', 'robbery', 'domestic', 'theft', 'assassination', 'rapist', 'rapes', 'murderer', 'victim', 'revenge', 'commits', 'serial', 'committing']
#
#
#
# CLUSTER NUMBER: 41
# WORDS:  ['ebola', 'virus', 'cured', 'measles', 'allergic', 'herpes', 'vaccines', 'allergies', 'infections', 'aids', 'vaccine', 'outbreak', 'allergy', 'diseases', 'infection', 'flu', 'infected', 'epidemic', 'viral', 'poisoning', 'viruses', 'vaccinated', 'strain', 'disease', 'vaccinations', 'vaccinate', 'vaccination', 'bacteria', 'cancer']
#
#
#
# CLUSTER NUMBER: 42
# WORDS:  ['sirius', 'hae', 'elsa', 'finn', 'mona', 'sparrow', 'jamie', 'walt', 'harry', 'anders', 'bonnie', 'arin', 'ollie', 'he', 'barry', 'iris', 'hermione', 'mel', 'gregor', 'oliver', 'voldemort', 'dumbledore', 'shepard', 'jenn', 'adnan', 'hans', 'hound', 'snape', 'geralt']
#
#
#
# CLUSTER NUMBER: 43
# WORDS:  ['roach', 'hydra', 'terran', 'tank', 'swarm', 'comp', 'strats', 'zerg', 'hive', 'reapers', 'playstyle', 'meta', 'merc', 'strat', 'murky', 'macro', 'creep', 'mechanic', 'base']
#
#
#
# CLUSTER NUMBER: 44
# WORDS:  ['dipped', 'whipped', 'drained', 'covered', 'shredded', 'choked', 'burned', 'starved', 'drowned', 'deflated', 'burnt', 'soaked', 'stuffed', 'melted', 'buried', 'eaten', 'crushed', 'swallowed', 'trapped', 'surrounded', 'torn', 'cracked']
#
#
#
# CLUSTER NUMBER: 45
# WORDS:  ['dies', 'meets', 'arises', 'progresses', 'develops', 'happens', 'feels', 'comes', 'grows', 'became', 'become', 'reacts', 'suffers', 'survives', 'becoming', 'spreads', 'learns', 'becomes', 'gets']
#
#
#
# CLUSTER NUMBER: 46
# WORDS:  ['asking', 'stressing', 'bragging', 'arguing', 'ranting', 'fuss', 'complaining', 'worry', 'thinking', 'telling', 'preaching', 'worrying', 'dreaming', 'whining', 'speaking', 'worries', 'debating', 'spouting', 'bitching', 'joking', 'exaggerating', 'forgetting', 'talking', 'bothering', 'hearing', 'rambling', 'clue', 'pretending', 'kidding', 'speculating', 'raging', 'chatting', 'fooling']
#
#
#
# CLUSTER NUMBER: 47
# WORDS:  ['profile', 'photograph', 'footage', 'selfie', 'facebook', 'instagram', 'images', 'photographs', 'video', 'twitter', 'photo', 'vids', 'cupid', 'nude', 'pic', 'tumblr', 'selfies', 'photos', 'tweet', 'shopped', 'vid', 'nudes', 'tinder', 'gif', 'snapchat', 'pictures', 'gallery', 'gifs', 'cam', 'screenshots', 'screenshot', 'picture', 'deviantart', 'vine', 'videos', 'photoshopped', 'pics']
#
#
#
# CLUSTER NUMBER: 48
# WORDS:  ['whose', 'whom', 'families', 'household', 'elderly', 'wives', 'rich', 'foster', 'who', 'homeless', 'lives', 'wealthy', 'deceased', 'possessions', 'individuals', 'handicapped', 'persons']
#
#
#
# CLUSTER NUMBER: 49
# WORDS:  ['glass', 'iron', 'metal', 'steel', 'ceramic', 'concrete', 'quartz', 'aluminum', 'wooden', 'brass', 'ore', 'composite', 'antique', 'cement', 'mold', 'pipes', 'charcoal', 'welding', 'titanium', 'metallic', 'clay', 'replica', 'wood', 'metals', 'stone', 'acrylic', 'stainless', 'brick', 'copper', 'materials', 'interior', 'exterior']
#
#
#
# CLUSTER NUMBER: 50
# WORDS:  ['talent', 'teamwork', 'initiative', 'sacrifices', 'passion', 'hustle', 'willpower', 'devotion', 'sacrifice', 'determination', 'progress', 'dedication', 'admire', 'intelligence', 'wisdom', 'persistence', 'intellect', 'knowledge', 'commitment', 'ethic', 'ambition', 'athleticism', 'charisma', 'willingness', 'prowess', 'faith', 'confidence', 'optimism', 'discipline', 'efforts', 'enthusiasm', 'ability', 'strength', 'desire', 'motivation', 'patience', 'restraint', 'courage', 'loyalty', 'effort', 'creativity']
#
#
#
# CLUSTER NUMBER: 51
# WORDS:  ['playthrough', 'missions', 'caravan', 'dungeons', 'urgent', 'mobs', 'rift', 'mission', 'heroic', 'companions', 'raid', 'bosses', 'trials', 'puzzle', 'raids', 'encounters', 'combat', 'frontier', 'battles', 'quest', 'treasure', 'arena', 'quests', 'adventure', 'rifts', 'chalice', 'puzzles', 'difficulty', 'dungeon', 'hunts', 'elders', 'boss', 'adventures', 'exploration', 'encounter']
#
#
#
# CLUSTER NUMBER: 52
# WORDS:  ['foam', 'taped', 'glued', 'tubes', 'seal', 'beads', 'wire', 'insulation', 'strips', 'sticks', 'wrapped', 'tape', 'glue', 'wrap', 'plastic', 'rubber', 'solder', 'duct', 'cardboard', 'lining']
#
#
#
# CLUSTER NUMBER: 53
# WORDS:  ['warframe', 'inquisition', 'raider', 'borderlands', 'unity', 'rpg', 'gta', 'cod', 'skyrim', 'diablo', 'madden', 'souls', 'hitman', 'starcraft', 'ops', 'kombat', 'payday', 'shooter', 'deus', 'duty', 'creed', 'morrowind', 'oblivion', 'shooters', 'bloodborne', 'civ', 'battlefront', 'skylines', 'uncharted', 'arkham', 'mordor', 'planetside', 'witcher', 'battlefield', 'arma', 'quake', 'multiplayer', 'hotline', 'titanfall', 'warcraft', 'warhammer', 'destiny', 'scrolls', 'hardline', 'halo', 'fallout', 'gameplay', 'bioshock', 'mmo', 'fifa', 'forza']
#
#
#
# CLUSTER NUMBER: 54
# WORDS:  ['consequently', 'significance', 'purpose', 'therefore', 'sense', 'hence', 'meaning', 'means', 'ergo', 'thereby', 'therefor', 'importance', 'value', 'thus']
#
#
#
# CLUSTER NUMBER: 55
# WORDS:  ['homer', 'hank', 'rob', 'woody', 'ross', 'gavin', 'marco', 'dan', 'larry', 'steve', 'simmons', 'jerry', 'scott', 'rodney', 'dave', 'palmer', 'sam', 'rick', 'pat', 'todd', 'monty', 'beck', 'dale', 'andy', 'glenn', 'roger', 'joe', 'rogan', 'ted', 'eddie', 'tony', 'gus', 'jim', 'charlie', 'carl', 'bruce', 'dennis', 'greg', 'chuck', 'walter', 'mike', 'simpson', 'glen', 'ron', 'bart', 'bob', 'jeff', 'kenny', 'fred', 'marty', 'bobby', 'frank', 'dana', 'bruno', 'mitch', 'gary', 'kelly', 'tom', 'keith', 'stan', 'mr', 'phil', 'jesse', 'tim', 'jackie', 'opie', 'ken', 'billy', 'doug', 'tommy', 'ricky', 'spencer', 'jimmy', 'steven', 'pete']
#
#
#
# CLUSTER NUMBER: 56
# WORDS:  ['considerably', 'hugely', 'progressively', 'massively', 'tremendously', 'infinitely', 'wildly', 'greatly', 'immensely', 'substantially', 'exponentially', 'drastically', 'significantly', 'steadily', 'vastly', 'dramatically', 'radically', 'severely', 'marginally', 'noticeably']
#
#
#
# CLUSTER NUMBER: 57
# WORDS:  ['remind', 'hear', 'see', 'assume', 'complain', 'specify', 'mention', 'know', 'bother', 'brag', 'trust', 'pretend', 'consider', 'tell', 'call', 'argue', 'admit', 'warn', 'forget', 'decide', 'do', 'enlighten', 'find', 'suggest', 'rephrase', 'speculate', 'believe', 'presume', 'happen', 'reiterate', 'clarify', 'say', 'choose', 'overlook', 'ask', 'inform', 'notice', 'chime', 'try']
#
#
#
# CLUSTER NUMBER: 58
# WORDS:  ['husky', 'fuzzy', 'dog', 'darling', 'bulldog', 'teddy', 'cutie', 'bunny', 'meow', 'pony', 'kitten', 'mister', 'sweetheart', 'sweetie', 'puppy', 'cat', 'momma', 'naughty', 'hamster', 'pet', 'kitty', 'badger', 'panda', 'fluffy', 'shepherd', 'pup', 'furry', 'daddy', 'mama']
#
#
#
# CLUSTER NUMBER: 59
# WORDS:  ['podcasts', 'director', 'writer', 'broadcast', 'guest', 'interviewing', 'radio', 'producer', 'segment', 'podcast', 'interviewer', 'caller', 'journalist', 'commentator', 'insider', 'reporter', 'broadcasting', 'announcer', 'interview', 'commentary', 'stern', 'listener', 'actor', 'celebrity', 'interviews', 'comedians', 'photographer', 'reviewer', 'comedian', 'performer']
#
#
#
# CLUSTER NUMBER: 60
# WORDS:  ['abusing', 'selecting', 'using', 'offending', 'filling', 'targeting', 'needing', 'applying', 'placing', 'swapping', 'skipping', 'separating', 'stopping', 'taking', 'tagging', 'aforementioned', 'cancelling', 'requiring', 'removing', 'stripping', 'replacing', 'adding', 'clearing', 'counting', 'avoiding', 'marking']
#
#
#
# CLUSTER NUMBER: 61
# WORDS:  ['hazard', 'striker', 'falcao', 'gerrard', 'neymar', 'alexis', 'messi', 'midfield', 'henderson', 'strikers', 'ronaldo', 'mata', 'mourinho', 'aguero', 'winger', 'silva', 'bale', 'pep', 'sterling', 'rooney', 'alonso', 'giroud', 'wingers', 'valencia', 'sanchez', 'suarez', 'costa', 'wenger', 'maria']
#
#
#
# CLUSTER NUMBER: 62
# WORDS:  ['scarce', 'available', 'manageable', 'accessible', 'doable', 'unused', 'playable', 'visible', 'necessary', 'obsolete', 'viable', 'functional', 'handy', 'useful', 'interchangeable', 'optional', 'suitable', 'compatible', 'functioning', 'applicable', 'relevant', 'sufficient', 'balanced', 'readable', 'unusable', 'worthwhile', 'usable']
#
#
#
# CLUSTER NUMBER: 63
# WORDS:  ['spouse', 'fiancee', 'girlfriend', 'boyfriends', 'girlfriends', 'hubby', 'ex', 'partner', 'coworker', 'wife', 'husband', 'neighbour', 'roommate', 'roommates', 'neighbor', 'friend', 'boyfriend', 'bf', 'colleague', 'gf', 'fiance']
#
#
#
# CLUSTER NUMBER: 64
# WORDS:  ['celebrating', 'defending', 'dislike', 'accusing', 'loving', 'fond', 'supporting', 'rooting', 'cheering', 'enjoy', 'praising', 'mocking', 'disliked', 'hating', 'hated', 'despise', 'thanking', 'hate', 'blaming', 'enjoying', 'calling', 'bashing', 'liking', 'criticizing']
#
#
#
# CLUSTER NUMBER: 65
# WORDS:  ['reliant', 'focused', 'focusing', 'capitalize', 'relying', 'burden', 'whim', 'relies', 'verge', 'emphasis', 'rely', 'basis', 'keen', 'behalf', 'relied', 'insist', 'focuses', 'focus', 'concentrate']
#
#
#
# CLUSTER NUMBER: 66
# WORDS:  ['irony', 'rhymes', 'pun', 'joke', 'brackets', 'rhyme', 'whoosh', 'tags', 'sarcasm', 'jokes', 'puns', 'punchline', 'spoilers', 'tag', 'title', 'gag', 'meme', 'spoiler', 'parenthesis', 'caption']
#
#
#
# CLUSTER NUMBER: 67
# WORDS:  ['backgrounds', 'blurry', 'screen', 'frames', 'px', 'shadows', 'photoshop', 'landscape', 'thumbnail', 'background', 'blur', 'zoom', 'clutter', 'fonts', 'cropped', 'display', 'rendering', 'resolutions', 'resolution', 'zoomed', 'layout', 'res', 'textures', 'screens', 'pixels', 'lighting', 'render', 'shading', 'framerate', 'pixel', 'icons', 'portrait', 'sprite', 'blurred', 'font', 'texture', 'wallpaper']
#
#
#
# CLUSTER NUMBER: 68
# WORDS:  ['whoops', 'misread', 'heres', 'picker', 'oops', 'googled', 'derp', 'formatting', 'typo', 'nevermind', 'forgot', 'typos', 'edit', 'autocorrect', 'nvm']
#
#
#
# CLUSTER NUMBER: 69
# WORDS:  ['formation', 'timing', 'practice', 'mechanism', 'fundamentals', 'tactics', 'mastering', 'scheme', 'technique', 'schemes', 'patterns', 'strategies', 'tricks', 'composition', 'pattern', 'positioning', 'form', 'tactic', 'drills', 'coordination', 'methods', 'mechanics', 'approach', 'rotations', 'placement', 'method', 'preparation', 'strategy', 'trick', 'techniques', 'position', 'plan']
#
#
#
# CLUSTER NUMBER: 70
# WORDS:  ['nigga', 'mans', 'guy', 'fam', 'lads', 'motherfucker', 'guys', 'mate', 'fucker', 'bro', 'fella', 'bruh', 'brah', 'lad', 'bud', 'dude', 'buddy', 'homie', 'kiddo', 'bloke', 'dawg', 'man', 'peeps']
#
#
#
# CLUSTER NUMBER: 71
# WORDS:  ['neutral', 'rather', 'universally', 'normally', 'traditional', 'regular', 'prefer', 'seem', 'necessarily', 'normal', 'standard', 'historically', 'tendency', 'nowadays', 'typically', 'tends', 'ideally', 'commonly', 'traditionally', 'generally', 'naturally', 'usual', 'versa', 'inherently', 'preferably', 'broadly', 'tend', 'general', 'tended', 'usually', 'specially', 'especially']
#
#
#
# CLUSTER NUMBER: 72
# WORDS:  ['candle', 'sparks', 'wings', 'lightning', 'blazing', 'ashes', 'ash', 'flame', 'burn', 'flaming', 'flames', 'candles', 'thunder', 'torch', 'blaze', 'fires', 'lit', 'fire', 'magma', 'burns', 'spark', 'burning']
#
#
#
# CLUSTER NUMBER: 73
# WORDS:  ['swords', 'darts', 'blades', 'whip', 'spears', 'archery', 'shovel', 'lance', 'pitchforks', 'wielding', 'handed', 'cane', 'scythe', 'rapier', 'bow', 'knives', 'piercing', 'katana', 'wield', 'hammer', 'mace', 'claw', 'crossbow', 'axe', 'axes', 'hammers', 'forged', 'arrows', 'fists', 'blade', 'claws', 'sword', 'bows', 'spear', 'knife', 'parry', 'weapon', 'duel', 'stab', 'slash', 'fist', 'moveset', 'dagger']
#
#
#
# CLUSTER NUMBER: 74
# WORDS:  ['owning', 'pursuing', 'acquired', 'acquisition', 'transferring', 'achieving', 'acquire', 'obtain', 'obtained', 'securing', 'obtaining', 'acquiring']
#
#
#
# CLUSTER NUMBER: 75
# WORDS:  ['koreans', 'europeans', 'locals', 'germans', 'greeks', 'peasants', 'folks', 'whites', 'australians', 'jews', 'immigrants', 'niggers', 'refugees', 'arabs', 'americans', 'indians', 'israelis', 'indigenous', 'peoples', 'blacks', 'natives', 'turks', 'tourists', 'outsiders', 'africans', 'canadians', 'people', 'brits', 'foreigners', 'mexicans', 'russians', 'asians', 'residents']
#
#
#
# CLUSTER NUMBER: 76
# WORDS:  ['driver', 'freeway', 'road', 'pedestrians', 'commuting', 'rail', 'ride', 'mile', 'taxi', 'pedestrian', 'roads', 'speeding', 'driving', 'passenger', 'bus', 'toll', 'cyclists', 'sidewalk', 'commute', 'parked', 'cyclist', 'uber', 'intersection', 'rides', 'rider', 'biker', 'ambulance', 'riders', 'streets', 'train', 'interstate', 'highway', 'cab', 'route', 'crossing', 'highways', 'bicycle', 'parking', 'drivers', 'traffic']
#
#
#
# CLUSTER NUMBER: 77
# WORDS:  ['sustained', 'recurring', 'mild', 'severity', 'suffer', 'experiencing', 'serious', 'constant', 'physical', 'lasting', 'endure', 'inducing', 'severe', 'intense', 'lifelong', 'fatal', 'extreme', 'persistent', 'prone', 'catastrophic', 'induced', 'permanent', 'crippling', 'sudden', 'noticeable', 'devastating', 'perpetual', 'defect', 'suffered', 'gradual', 'lingering', 'drastic', 'profound', 'continuous', 'temporary', 'minor']
#
#
#
# CLUSTER NUMBER: 78
# WORDS:  ['slapping', 'chilling', 'stealing', 'busting', 'sticking', 'spraying', 'dropping', 'swinging', 'laying', 'catching', 'tossing', 'cracking', 'staring', 'tearing', 'blasting', 'breaking', 'rocking', 'chopping', 'dragging', 'pulling', 'slamming', 'snapping', 'blowing', 'pushing', 'falling', 'shoving', 'wrecking', 'knocking', 'sitting', 'kicking', 'locking', 'spinning', 'sneaking', 'hitting', 'crashing', 'passing', 'choking', 'punching', 'banging', 'tying', 'waving', 'hopping', 'sucking', 'jumping', 'getting', 'standing', 'facing', 'picturing', 'shutting', 'poking', 'crushing', 'floating', 'hovering', 'stepping', 'rolling', 'reaching', 'sliding', 'putting', 'throwing', 'turning', 'pounding', 'slipping', 'settling', 'stomping', 'cutting', 'bouncing', 'smashing', 'tripping', 'ripping', 'backing', 'carrying', 'running', 'bringing', 'walking', 'holding', 'hanging', 'handing', 'rushing', 'flipping', 'dumping', 'popping', 'grabbing', 'creeping', 'crawling', 'bumping', 'ing', 'sinking']
#
#
#
# CLUSTER NUMBER: 79
# WORDS:  ['caribbean', 'international', 'atlantic', 'aussie', 'australia', 'pacific', 'aus', 'sydney', 'zealand', 'australian', 'regional', 'indies', 'americas', 'melbourne', 'continental']
#
#
#
# CLUSTER NUMBER: 80
# WORDS:  ['liquid', 'mix', 'medium', 'concentrated', 'dip', 'dissolve', 'blends', 'coating', 'synthetic', 'substitute', 'layers', 'dab', 'coated', 'mixes', 'powder', 'layer', 'blender', 'compound', 'mixture', 'blend', 'blending', 'grain', 'concentration', 'blended', 'spray', 'mixing']
#
#
#
# CLUSTER NUMBER: 81
# WORDS:  ['fitted', 'catering', 'fitting', 'geared', 'suits', 'tuned', 'oriented', 'accommodate', 'suited', 'crafted', 'fits', 'tailored', 'cater', 'fit', 'designed', 'aimed', 'targeted', 'tailor', 'casual']
#
#
#
# CLUSTER NUMBER: 82
# WORDS:  ['sad', 'indifferent', 'hopeful', 'skeptical', 'ashamed', 'stoked', 'optimistic', 'relieved', 'hoping', 'interested', 'curious', 'conflicted', 'glad', 'doubtful', 'ecstatic', 'pumped', 'concerned', 'excited', 'happy', 'worried', 'cautious', 'bummed', 'hyped', 'unsure', 'confident', 'uncertain', 'nostalgic', 'thankful', 'wary', 'grateful', 'proud']
#
#
#
# CLUSTER NUMBER: 83
# WORDS:  ['juicy', 'berries', 'mushroom', 'grapes', 'yum', 'strawberries', 'fruits', 'berry', 'mango', 'lime', 'icing', 'watermelon', 'flavor', 'sour', 'peanuts', 'lemon', 'apples', 'raspberry', 'pickle', 'flavour', 'grape', 'bananas', 'jelly', 'cracker', 'mint', 'pineapple', 'spice', 'carrot', 'nuts', 'strawberry', 'kiwi', 'oranges', 'cherry', 'banana', 'fruit', 'crunch', 'ripe']
#
#
#
# CLUSTER NUMBER: 84
# WORDS:  ['fidelity', 'dynamic', 'execution', 'consistency', 'communication', 'compatibility', 'parity', 'balancing', 'structural', 'sampling', 'graphical', 'simplicity', 'development', 'management', 'stability', 'visibility', 'improvement', 'optimization', 'reliability', 'clarity', 'visual', 'dependency', 'transparency', 'latency', 'longevity', 'performance', 'handling', 'optimized', 'detection', 'complexity', 'precision', 'flexibility', 'implementation', 'integration', 'technical', 'efficiency', 'troubleshooting']
#
#
#
# CLUSTER NUMBER: 85
# WORDS:  ['imo', 'likely', 'potentially', 'definately', 'maybe', 'probably', 'ofcourse', 'hopefully', 'atleast', 'presumably', 'obviously', 'be', 'prob', 'definitively', 'seems', 'realistically', 'imho', 'clearly', 'least', 'perhaps', 'possibly', 'guess', 'arguably', 'reckon', 'prolly', 'theoretically', 'suppose', 'undoubtedly', 'certainly', 'definitely', 'hardly', 'course', 'surely', 'think']
#
#
#
# CLUSTER NUMBER: 86
# WORDS:  ['emotion', 'jealousy', 'pride', 'envy', 'rage', 'frustration', 'misery', 'loathing', 'visceral', 'hatred', 'bitterness', 'desperation', 'pity', 'anger', 'resentment', 'ego', 'impulse', 'sadness', 'emotional', 'loneliness', 'lust', 'struggle', 'temper', 'fear', 'despair', 'insecurity', 'grief', 'disgust', 'paranoia', 'guilt', 'grudge']
#
#
#
# CLUSTER NUMBER: 87
# WORDS:  ['african', 'belgian', 'thai', 'american', 'egyptian', 'foreigner', 'british', 'norwegian', 'brit', 'italian', 'texan', 'persian', 'cuban', 'mexican', 'korean', 'chinese', 'indian', 'danish', 'swiss', 'japanese', 'nordic', 'immigrant', 'canadian', 'asian', 'spanish', 'hispanic', 'irish', 'welsh', 'vietnamese', 'russian', 'french', 'swedish', 'finnish', 'portuguese', 'foreign', 'scottish', 'turkish', 'brazilian', 'greek', 'ukrainian', 'european', 'dutch', 'pakistani', 'german', 'polish']
#
#
#
# CLUSTER NUMBER: 88
# WORDS:  ['satirical', 'crude', 'prank', 'amusing', 'humour', 'humor', 'quirky', 'comedic', 'funny', 'cringey', 'cringe', 'humorous', 'flattering', 'parody', 'playful', 'inappropriate', 'poetic', 'goofy', 'rhetorical', 'hearted', 'banter', 'witty', 'subtle', 'morbid', 'lighten', 'comical', 'satire', 'cheeky', 'ironic', 'charming', 'clever', 'dramatic']
#
#
#
# CLUSTER NUMBER: 89
# WORDS:  ['th', 'tenth', 'seventh', 'third', 'first', 'sixth', 'nd', 'st', 'fifth', 'rd', 'second', 'fourth']
#
#
#
# CLUSTER NUMBER: 90
# WORDS:  ['handgun', 'magazine', 'rounds', 'guns', 'tec', 'airsoft', 'mag', 'shotgun', 'muzzle', 'firearm', 'barrel', 'bullet', 'taser', 'magnum', 'barrels', 'sights', 'ammunition', 'pistol', 'magazines', 'bullets', 'colt', 'firearms', 'glock', 'gun', 'sig', 'pistols', 'revolver', 'rifles', 'outlaw', 'shotguns', 'mags', 'concealed', 'rifle', 'caliber', 'recoil', 'holster']
#
#
#
# CLUSTER NUMBER: 91
# WORDS:  ['straw', 'hominem', 'claim', 'assumptions', 'observation', 'notion', 'analogy', 'claims', 'statement', 'premises', 'misconception', 'prediction', 'accusation', 'theory', 'statistic', 'proposition', 'generalization', 'objection', 'theories', 'fallacy', 'dichotomy', 'premise', 'remark', 'myth', 'anecdote', 'assumption', 'rebuttal', 'hypothesis', 'conclusion', 'strawman', 'argument', 'arguments', 'logic', 'generalizations', 'statements', 'assertion', 'concept', 'dilemma', 'reasoning', 'guesses', 'point']
#
#
#
# CLUSTER NUMBER: 92
# WORDS:  ['selected', 'edited', 'pending', 'checked', 'spammed', 'flagged', 'uploaded', 'verified', 'formatted', 'censored', 'deleted', 'copied', 'leaked', 'filtered', 'canceled', 'tagged', 'banned', 'scanned', 'cancelled', 'archived', 'recorded', 'added', 'tested', 'shadowbanned', 'detected', 'updated', 'blocked', 'pasted', 'removed', 'notified', 'marked', 'delayed', 'clicked', 'approved', 'posted', 'hacked', 'logged']
#
#
#
# CLUSTER NUMBER: 93
# WORDS:  ['crits', 'procs', 'multiplier', 'mitigation', 'stuns', 'debuff', 'stun', 'durability', 'survivability', 'damage', 'utility', 'dmg', 'elemental', 'projectiles', 'dps', 'penetration', 'passive', 'hitbox', 'cooldown', 'modifier', 'proc', 'mobility', 'cc', 'ranged', 'aoe', 'burst', 'crit', 'projectile', 'phys', 'autos', 'lifesteal', 'scaling', 'toughness']
#
#
#
# CLUSTER NUMBER: 94
# WORDS:  ['smaller', 'scaled', 'wider', 'lesser', 'sizes', 'sized', 'greater', 'broader', 'small', 'bigger', 'scale', 'smallest', 'shrinking', 'larger', 'tiny', 'large', 'size', 'largest']
#
#
#
# CLUSTER NUMBER: 95
# WORDS:  ['kung', 'ng', 'di', 'li', 'ba', 'fu', 'ga', 'chi', 'ding', 'mo', 'lang', 'jo', 'ke', 'ma', 'ki', 'na', 'cha', 'wa', 'ka', 'hai', 'pa', 'ni', 'ko']
#
#
#
# CLUSTER NUMBER: 96
# WORDS:  ['terminal', 'manual', 'header', 'firmware', 'click', 'configured', 'commands', 'shortcuts', 'menu', 'key', 'command', 'boot', 'log', 'alias', 'repo', 'url', 'buttons', 'settings', 'defaults', 'select', 'installation', 'config', 'configure', 'installer', 'panel', 'manually', 'menus', 'prompt', 'ctrl', 'tabs', 'cursor', 'load', 'tab', 'bios', 'install', 'module', 'setup', 'headers', 'debug', 'configuration', 'kernel', 'startup']
#
#
#
# CLUSTER NUMBER: 97
# WORDS:  ['mic', 'headphone', 'headphones', 'flashlight', 'surround', 'nikon', 'sensors', 'speaker', 'cameras', 'aperture', 'mics', 'headset', 'speakers', 'stereo', 'antenna', 'mixer', 'kinect', 'projector', 'analog', 'scanner', 'optical', 'lenses', 'lens', 'telescope', 'receiver', 'sensor', 'microphone', 'camera', 'optic', 'shutter', 'audio', 'optics']
#
#
#
# CLUSTER NUMBER: 98
# WORDS:  ['leash', 'ft', 'feet', 'toe', 'inches', 'tail', 'inch', 'tall', 'pole', 'footing', 'paw', 'stride', 'step', 'ball', 'foot', 'wheelchair']
#
#
#
# CLUSTER NUMBER: 99
# WORDS:  ['ti', 'intel', 'motherboard', 'crossfire', 'gb', 'nvidia', 'specs', 'processor', 'benchmarks', 'quad', 'processors', 'overclock', 'graphics', 'gtx', 'ram', 'cores', 'psu', 'mobo', 'ghz', 'gpu', 'cooler', 'acer', 'cpu', 'bottleneck', 'evo', 'mhz', 'asus', 'vidia', 'amd', 'ssd', 'hz', 'rig', 'chip', 'core', 'radeon', 'corsair', 'overclocking', 'overclocked', 'pentium', 'gigabyte', 'dual', 'gigs', 'fps', 'overkill', 'benchmark']

# %%
# Test the clusters
word_centroid_map['swords']
# Out:
# 73
